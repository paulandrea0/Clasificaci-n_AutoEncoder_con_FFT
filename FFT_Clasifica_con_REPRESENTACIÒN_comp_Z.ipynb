# %% [markdown]
# <a href="https://colab.research.google.com/github/paulandrea0/Clasificaci-n_AutoEncoder_con_FFT/blob/main/FFT_Clasifica_con_REPRESENTACI%C3%92N_comp_Z.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Set de datos**

# %% [markdown]
# El set de datos corresponde a señales de sismos volcánicos del tipo VT, LP y Tor

# %% [markdown]
# **1.1 Lectura de datos desde Google Drive**

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# Set de entrenamiento y validación para seãnales sísmicas en el componente Z

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import math

#%reset
df_test_1 = pd.read_csv('/gdrive/MyDrive/Sismos/VT_Z_teste.csv')
df_train_1 = pd.read_csv('/gdrive/MyDrive/Sismos/VT_Z_train.csv') 
df_test_2 = pd.read_csv('/gdrive/MyDrive/Sismos/LP_Z_teste.csv')
df_train_2 = pd.read_csv('/gdrive/MyDrive/Sismos/LP_Z_train.csv')
df_test_3 = pd.read_csv('/gdrive/MyDrive/Sismos/TOR_Z_teste.csv')
df_train_3 = pd.read_csv('/gdrive/MyDrive/Sismos/TOR_Z_train.csv')

# %% [markdown]
# **1.2 Aplicando función Mean para quitar el OffSet de los datos**
# Normalización a 3000 muestras por registro.

# %%
# Creando función para retirar el offset de los datos en DataFrame
def mean_norma(df_input):
        return df_input.apply(lambda x: (x-x.mean()), axis=1)  

df_mean_test_1 = mean_norma(df_test_1)  # Señales VT
df_mean_train_1 = mean_norma(df_train_1)
df_mean_test_2 = mean_norma(df_test_2)  # Señales LP
df_mean_train_2 = mean_norma(df_train_2)
df_mean_test_3 = mean_norma(df_test_3)  # Señales Tor
df_mean_train_3 = mean_norma(df_train_3)

print(df_mean_train_1.shape)
print(df_mean_test_1.shape)
print(df_mean_train_2.shape)
print(df_mean_test_2.shape)
print(df_mean_train_3.shape)
print(df_mean_test_3.shape)

# Convirtiendo el dataframe en array
d_train_1 = df_mean_train_1.values
d_train_1 = d_train_1[:, 0:3000]
d_test_1 = df_mean_test_1.values
d_test_1 = d_test_1[:, 0:3000]

d_train_2 = df_mean_train_2.values
d_train_2 = d_train_2[:, 0:3000]
d_test_2 = df_mean_test_2.values
d_test_2 = d_test_2[:, 0:6000]

d_train_3 = df_mean_train_3.values
d_train_3 = d_train_3[:, 0:3000]
d_test_3 = df_mean_test_3.values
d_test_3 = d_test_3[:, 0:3000]

# Dibujando la señal orioginal
n = 3000
fs = 50 # frecuencia de muestreo
t = np.linspace(0,fs,n)
plt.figure(1, figsize=(30, 4))
plt.subplot(231)
plt.plot(t, d_train_1[60])
plt.subplot(232)
plt.plot(t, d_train_2[18])
plt.subplot(233) 
plt.plot(t, d_train_3[38])
plt.subplot(234)
plt.plot(t, d_test_1[44])
plt.subplot(235)
plt.plot(t, d_test_2[34])
plt.subplot(236)
plt.plot(t, d_test_3[4])
# Out:
# (1480, 13348)
# (256, 10993)
# (362, 3000)
# (40, 3000)
# (61, 21494)
# (6, 27408)

# %% [markdown]
# **1.3 Eliminando valores NaN de los arreglos Numpy**

# %%
# Quitando los valores NaN de los array numpy

# Señales VT
d_train_1[np.isnan(d_train_1)] = 0.0
d_test_1[np.isnan(d_test_1)] = 0.0
print(d_train_1.shape)
print(d_test_1.shape)

# Señales LP
d_train_2[np.isnan(d_train_2)] = 0.0
d_test_2[np.isnan(d_test_2)] = 0.0
print(d_train_2.shape)
print(d_test_2.shape)

# Señales Tor`
d_train_3[np.isnan(d_train_3)] = 0.0
d_test_3[np.isnan(d_test_3)] = 0.0
print(d_train_3.shape)
print(d_test_3.shape)

# Graficando
plt.figure(2, figsize=(15, 4))
plt.subplot(231)
plt.plot(t, d_train_1[60])
plt.subplot(232)
plt.plot(t, d_train_2[18])
plt.subplot(233) 
plt.plot(t, d_train_3[38])
plt.subplot(234)
plt.plot(t, d_test_1[44])
plt.subplot(235)
plt.plot(t, d_test_2[34])
plt.subplot(236)
plt.plot(t, d_test_3[4])
# Out:
# (1480, 3000)
# (256, 3000)
# (362, 3000)
# (40, 3000)
# (61, 3000)
# (6, 3000)

# %% [markdown]
# **1.4 Aplicando transformada de Fourier al DataSet**

# %% [markdown]
# Al aplicar la transformada de Fourier a mis datos, estos pueden quedar reducidos a la mitad en cuanto a los elementos a ser presentados en la entrada del autoencoder, así mejorando el rendimiento. Además las carácterísticas a ser aprendidas por el modelo pueden resultar más claras.

# %%
import scipy.fft as sfft

# Transformada de Fourier
n2 = 1500
t2 = np.linspace(0,fs,n2) # creando un vector de tiempo
print(len(t2))

f = sfft.fftshift(sfft.fftfreq(n=len(t2), d=1./fs))

# Señales VT
S_train_1 = sfft.fftshift(sfft.fft(d_train_1))
SA_train_1 = np.absolute(S_train_1)
SA_train_1 = SA_train_1[:, 1500:3000]

S_test_1 = sfft.fftshift(sfft.fft(d_test_1))
SA_test_1 = np.absolute(S_test_1)
SA_test_1 = SA_test_1[:, 1500:3000]

# Señales LP
S_train_2 = sfft.fftshift(sfft.fft(d_train_2))
SA_train_2 = np.absolute(S_train_2)
SA_train_2 = SA_train_2[:, 1500:3000]

S_test_2 = sfft.fftshift(sfft.fft(d_test_2))
SA_test_2 = np.absolute(S_test_2)
SA_test_2 = SA_test_2[:, 1500:3000]

# Señales Tor
S_train_3 = sfft.fftshift(sfft.fft(d_train_3))
SA_train_3 = np.absolute(S_train_3)
SA_train_3 = SA_train_3[:, 1500:3000]

S_test_3 = sfft.fftshift(sfft.fft(d_test_3))
SA_test_3 = np.absolute(S_test_3)
SA_test_3 = SA_test_3[:, 1500:3000]

print(SA_train_1.shape, SA_test_1.shape)
print(SA_train_2.shape, SA_test_2.shape)
print(SA_train_3.shape, SA_test_3.shape)

# Graficando
plt.figure(3, figsize=(15, 4))
plt.subplot(231)
plt.plot(f, SA_train_1[60])
plt.subplot(232)
plt.plot(f, SA_train_2[18])
plt.subplot(233) 
plt.plot(f, SA_train_3[38])
plt.subplot(234)
plt.plot(f, SA_test_1[44])
plt.subplot(235)
plt.plot(f, SA_test_2[34])
plt.subplot(236)
plt.plot(f, SA_test_3[4])
# Out:
# 1500
# (1480, 1500) (256, 1500)
# (362, 1500) (40, 1500)
# (61, 1500) (6, 1500)

# %% [markdown]
# **1.5 Normalización**

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

# Señales VT
D_train_s1 = min_max_scaler.fit_transform(SA_train_1)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(SA_train_1), np.max(SA_train_1)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(D_train_s1), np.max(D_train_s1))) 
D_test_s1 = min_max_scaler.transform(SA_test_1)  

# Señales LP
D_train_s2 = min_max_scaler.fit_transform(SA_train_2)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(SA_train_2), np.max(SA_train_2)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(D_train_s2), np.max(D_train_s2))) 
D_test_s2 = min_max_scaler.transform(SA_test_2)  

# Señales Tor
D_train_s3 = min_max_scaler.fit_transform(SA_train_3)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(SA_train_3), np.max(SA_train_3)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(D_train_s3), np.max(D_train_s3))) 
D_test_s3 = min_max_scaler.transform(SA_test_3)  

# Graficando
plt.figure(3, figsize=(20, 4))
plt.subplot(231)
plt.plot(t2, D_train_s1[60])
plt.subplot(232)
plt.plot(t2, D_train_s2[18])
plt.subplot(233) 
plt.plot(t2, D_train_s3[38])
plt.subplot(234)
plt.plot(t2, D_test_s1[44])
plt.subplot(235)
plt.plot(t2, D_test_s2[34])
plt.subplot(236)
plt.plot(t2, D_test_s3[4])
# Out:
# Mínimo y máximo originales: 0.0, 125131869.3
# Mínimo y máximo normalizado: 0.0, 1.0
# Mínimo y máximo originales: 0.0, 10438146.7
# Mínimo y máximo normalizado: 0.0, 1.0
# Mínimo y máximo originales: 0.0, 6119343.5
# Mínimo y máximo normalizado: 0.0, 1.0

# %% [markdown]
# # **2. Modelo AutoEncoder para extraer Características (Representaciones de menor dimensión)**

# %% [markdown]
# Importamos TensorFlow 2 que incluye Keras

# %%
# %tensorflow_version 2.x
import tensorflow as tf
print('version de TensorFlow:' + tf.__version__)
# Out:
# version de TensorFlow:2.8.2

# %% [markdown]
# **2.1 Configuración de la arquitectura del Autoencoder**

# %% [markdown]
# Configuramos la arquitectura del modelo de Autoencoder. Esta configuración será reallizada teneindo en cuenta el set de entrenamiento para el conjunto de señales VT.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Activation
from tensorflow.keras import Sequential
from keras.regularizers import l2 # cuando hay sobreajuste la regularización ayuda
# a decartar valores altos en la función de costo. Se puede colocar en cualquier capa
from keras.layers import Dropout  #apagar aleatoriamente algunas neuronas, 
# ayudando a eliminar el sobreajuste
from keras.callbacks import EarlyStopping
np.random.seed(23)

dim_entrada = D_train_s1.shape[1]      
entrada = Input(shape=(dim_entrada,))
print(D_train_s1.shape[1])             

# Encoder
x = Dense(800, activation='relu', kernel_regularizer=l2(0.005))(entrada)
x = Dropout(0.25)(x)
x = Dense(500, activation='relu', kernel_regularizer=l2(0.005))(x)
x = Dropout(0.25)(x)
x = Dense(200, activation='relu')(x)
x = Dropout(0.25)(x)
encoded = Dense(50, activation='relu', name='bottleneck_layer')(x)

# Decoder 
x = Dense(200, activation='relu')(encoded)
x = Dropout(0.25)(x)
x = Dense(500, activation='relu')(x)
x = Dropout(0.25)(x)
x = Dense(800, activation='relu', kernel_regularizer=l2(0.005))(x)
x = Dropout(0.25)(x)
decoded = Dense(1500, activation='sigmoid')(x)

# autoencoder = entrada + decoder (que contiene el encoder)
autoencoder = Model(inputs=entrada, outputs=decoded)

autoencoder.summary()
# Out:
# 1500
# Model: "model_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 1500)]            0
#
#  dense_35 (Dense)            (None, 800)               1200800
#
#  dropout_30 (Dropout)        (None, 800)               0
#
#  dense_36 (Dense)            (None, 500)               400500
#
#  dropout_31 (Dropout)        (None, 500)               0
#
#  dense_37 (Dense)            (None, 200)               100200
#
#  dropout_32 (Dropout)        (None, 200)               0
#
#  bottleneck_layer (Dense)    (None, 50)                10050
#
#  dense_38 (Dense)            (None, 200)               10200
#
#  dropout_33 (Dropout)        (None, 200)               0
#
#  dense_39 (Dense)            (None, 500)               100500
#
#  dropout_34 (Dropout)        (None, 500)               0
#
#  dense_40 (Dense)            (None, 800)               400800
#
#  dropout_35 (Dropout)        (None, 800)               0
#
#  dense_41 (Dense)            (None, 1500)              1201500
#
# =================================================================
# Total params: 3,424,550
# Trainable params: 3,424,550
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **2.2 Optimización y Entrenamiento**

# %% [markdown]
# La pérdida corresponderá al error absoluto medio(Mean Absolute Error, MAE.
# El optimizador será adam.
# Debido a que el set de datos (entrenamiento y validación) mayor corresponde a las señales sísmicas VT, el autoencoder es entrenado con este set de datos, teniendo en cuenta el desbalance que hay con los demás sets.

# %% [markdown]
# **2.2.1 Entrenando para obtener Representación para Señales VT**

# %%
autoencoder1 = Model(inputs=entrada, outputs=decoded)
autoencoder1.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
historia = autoencoder1.fit(D_train_s1, D_train_s1,    
                           epochs=25,
                           batch_size=150,
                           validation_data=(D_test_s1, D_test_s1),    
                           shuffle=True)
# Out:
# Epoch 1/25
# 10/10 [==============================] - 1s 26ms/step - loss: 9.5991 - accuracy: 0.0000e+00 - val_loss: 7.0881 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 10/10 [==============================] - 0s 11ms/step - loss: 5.5343 - accuracy: 0.0000e+00 - val_loss: 3.6732 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 10/10 [==============================] - 0s 11ms/step - loss: 2.7574 - accuracy: 6.7568e-04 - val_loss: 1.8684 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 10/10 [==============================] - 0s 10ms/step - loss: 1.3868 - accuracy: 6.7568e-04 - val_loss: 0.9025 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6530 - accuracy: 6.7568e-04 - val_loss: 0.4123 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2932 - accuracy: 6.7568e-04 - val_loss: 0.1833 - val_accuracy: 0.0000e+00
# Epoch 7/25
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1289 - accuracy: 6.7568e-04 - val_loss: 0.0822 - val_accuracy: 0.0078
# Epoch 8/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0573 - accuracy: 0.0223 - val_loss: 0.0381 - val_accuracy: 0.0000e+00
# Epoch 9/25
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0266 - accuracy: 0.0689 - val_loss: 0.0200 - val_accuracy: 0.0742
# Epoch 10/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0142 - accuracy: 0.1878 - val_loss: 0.0130 - val_accuracy: 0.2695
# Epoch 11/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0093 - accuracy: 0.2453 - val_loss: 0.0105 - val_accuracy: 0.2695
# Epoch 12/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0076 - accuracy: 0.2480 - val_loss: 0.0093 - val_accuracy: 0.2852
# Epoch 13/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0070 - accuracy: 0.2412 - val_loss: 0.0090 - val_accuracy: 0.2695
# Epoch 14/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0068 - accuracy: 0.2324 - val_loss: 0.0089 - val_accuracy: 0.2852
# Epoch 15/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0068 - accuracy: 0.2527 - val_loss: 0.0089 - val_accuracy: 0.2695
# Epoch 16/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0067 - accuracy: 0.2622 - val_loss: 0.0089 - val_accuracy: 0.2695
# Epoch 17/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0067 - accuracy: 0.2392 - val_loss: 0.0089 - val_accuracy: 0.2695
# Epoch 18/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0069 - accuracy: 0.2534 - val_loss: 0.0089 - val_accuracy: 0.2852
# Epoch 19/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0072 - accuracy: 0.2338 - val_loss: 0.0102 - val_accuracy: 0.2852
# Epoch 20/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0074 - accuracy: 0.2264 - val_loss: 0.0100 - val_accuracy: 0.0742
# Epoch 21/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0077 - accuracy: 0.0757 - val_loss: 0.0101 - val_accuracy: 0.0312
# Epoch 22/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0070 - accuracy: 0.0622 - val_loss: 0.0092 - val_accuracy: 0.0742
# Epoch 23/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0068 - accuracy: 0.2047 - val_loss: 0.0089 - val_accuracy: 0.2695
# Epoch 24/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0070 - accuracy: 0.2243 - val_loss: 0.0096 - val_accuracy: 0.2695
# Epoch 25/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0071 - accuracy: 0.2514 - val_loss: 0.0094 - val_accuracy: 0.2852

# %%
import matplotlib.pyplot as plt
plt.figure(5, figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(historia.history["loss"], label="Pérdida set entrenamiento")
plt.plot(historia.history["val_loss"], label="Pérdida set prueba")
plt.xlabel('Epocas')
plt.legend()
plt.subplot(1,2,2)
plt.plot(historia.history["accuracy"], label="Tasa de acierto en entrenamiento")
plt.plot(historia.history["val_accuracy"], label="Tasa de acierto en teste")
plt.xlabel('Epocas')
plt.legend()

# %% [markdown]
# Una vez entrenado el modelo con el set correspondiente a las señales VT, se extrae la representación contenida en el "bottleneck" del AutoEncoder.

# %%
bottleneck = Model(entrada, encoded)
rep_test_1 = bottleneck.predict(D_test_s1)
print(rep_test_1.shape)
# Out:
# (256, 50)

# %% [markdown]
# **2.2.2 Entrenando para obtener Representación para Señales LP**

# %% [markdown]
# Usamos la misma arquitectura del autoencoder, sin embargo, entrenamos con señales LP

# %%
autoencoder2 = Model(inputs=entrada, outputs=decoded)
autoencoder2.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
historia = autoencoder2.fit(D_train_s2, D_train_s2,    
                           epochs=25,
                           batch_size=50,
                           validation_data=(D_test_s2, D_test_s2),    
                           shuffle=True)
# Out:
# Epoch 1/25
# 8/8 [==============================] - 1s 30ms/step - loss: 0.1895 - accuracy: 0.0055 - val_loss: 0.0769 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0709 - accuracy: 0.0138 - val_loss: 0.0733 - val_accuracy: 0.0750
# Epoch 3/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0684 - accuracy: 0.0773 - val_loss: 0.0731 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0677 - accuracy: 0.0083 - val_loss: 0.0721 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0667 - accuracy: 0.0028 - val_loss: 0.0713 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0660 - accuracy: 0.0000e+00 - val_loss: 0.0706 - val_accuracy: 0.0000e+00
# Epoch 7/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0652 - accuracy: 0.0000e+00 - val_loss: 0.0699 - val_accuracy: 0.0000e+00
# Epoch 8/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0646 - accuracy: 0.0028 - val_loss: 0.0693 - val_accuracy: 0.0000e+00
# Epoch 9/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0640 - accuracy: 0.0000e+00 - val_loss: 0.0688 - val_accuracy: 0.0000e+00
# Epoch 10/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0635 - accuracy: 0.0000e+00 - val_loss: 0.0683 - val_accuracy: 0.0000e+00
# Epoch 11/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0631 - accuracy: 0.0000e+00 - val_loss: 0.0680 - val_accuracy: 0.0000e+00
# Epoch 12/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0627 - accuracy: 0.0000e+00 - val_loss: 0.0676 - val_accuracy: 0.0000e+00
# Epoch 13/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0624 - accuracy: 0.0028 - val_loss: 0.0673 - val_accuracy: 0.0000e+00
# Epoch 14/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0621 - accuracy: 0.0028 - val_loss: 0.0671 - val_accuracy: 0.0000e+00
# Epoch 15/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0619 - accuracy: 0.0055 - val_loss: 0.0668 - val_accuracy: 0.0000e+00
# Epoch 16/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0617 - accuracy: 0.0000e+00 - val_loss: 0.0666 - val_accuracy: 0.0000e+00
# Epoch 17/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0615 - accuracy: 0.0000e+00 - val_loss: 0.0665 - val_accuracy: 0.0000e+00
# Epoch 18/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0613 - accuracy: 0.0000e+00 - val_loss: 0.0663 - val_accuracy: 0.0000e+00
# Epoch 19/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0612 - accuracy: 0.0000e+00 - val_loss: 0.0662 - val_accuracy: 0.0000e+00
# Epoch 20/25
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0610 - accuracy: 0.0000e+00 - val_loss: 0.0661 - val_accuracy: 0.0000e+00
# Epoch 21/25
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0609 - accuracy: 0.0000e+00 - val_loss: 0.0660 - val_accuracy: 0.0000e+00
# Epoch 22/25
# 8/8 [==============================] - 0s 24ms/step - loss: 0.0608 - accuracy: 0.0000e+00 - val_loss: 0.0660 - val_accuracy: 0.0000e+00
# Epoch 23/25
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0711 - accuracy: 0.0110 - val_loss: 0.0759 - val_accuracy: 0.0750
# Epoch 24/25
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0740 - accuracy: 0.0552 - val_loss: 0.0807 - val_accuracy: 0.0000e+00
# Epoch 25/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0747 - accuracy: 0.0580 - val_loss: 0.0768 - val_accuracy: 0.0750

# %%
import matplotlib.pyplot as plt
plt.figure(5, figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(historia.history["loss"], label="Pérdida set entrenamiento")
plt.plot(historia.history["val_loss"], label="Pérdida set prueba")
plt.xlabel('Epocas')
plt.legend()
plt.subplot(1,2,2)
plt.plot(historia.history["accuracy"], label="Tasa de acierto en entrenamiento")
plt.plot(historia.history["val_accuracy"], label="Tasa de acierto en teste")
plt.xlabel('Epocas')
plt.legend()

# %% [markdown]
# Una vez entrenado el modelo con el set correspondiente a las señales LP, se extrae la representación contenida en el "bottleneck" del AutoEncoder.

# %%
bottleneck = Model(entrada, encoded)
rep_test_2 = bottleneck.predict(D_test_s2)
print(rep_test_2.shape)
# Out:
# (40, 50)

# %% [markdown]
# **2.2.3 Entrenando para obtener Representación para Señales Tor**

# %% [markdown]
# Usamos la misma arquitectura del autoencoder, sin embargo, entrenamos con señales Tor

# %%
autoencoder3 = Model(inputs=entrada, outputs=decoded)
autoencoder3.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
historia = autoencoder3.fit(D_train_s3, D_train_s3,    
                           epochs=25,
                           batch_size=2,
                           validation_data=(D_test_s3, D_test_s3),    
                           shuffle=True)
# Out:
# Epoch 1/25
# 31/31 [==============================] - 2s 17ms/step - loss: 0.1249 - accuracy: 0.0164 - val_loss: 0.1309 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1323 - accuracy: 0.0164 - val_loss: 0.1394 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1286 - accuracy: 0.0164 - val_loss: 0.1327 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 31/31 [==============================] - 0s 6ms/step - loss: 0.1245 - accuracy: 0.0164 - val_loss: 0.1309 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 31/31 [==============================] - 0s 6ms/step - loss: 0.1235 - accuracy: 0.0164 - val_loss: 0.1309 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1243 - accuracy: 0.0328 - val_loss: 0.1322 - val_accuracy: 0.0000e+00
# Epoch 7/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1245 - accuracy: 0.0000e+00 - val_loss: 0.1311 - val_accuracy: 0.0000e+00
# Epoch 8/25
# 31/31 [==============================] - 0s 6ms/step - loss: 0.1278 - accuracy: 0.0000e+00 - val_loss: 0.1782 - val_accuracy: 0.0000e+00
# Epoch 9/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1509 - accuracy: 0.0000e+00 - val_loss: 0.1396 - val_accuracy: 0.0000e+00
# Epoch 10/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1275 - accuracy: 0.0000e+00 - val_loss: 0.1324 - val_accuracy: 0.0000e+00
# Epoch 11/25
# 31/31 [==============================] - 0s 6ms/step - loss: 0.1310 - accuracy: 0.0164 - val_loss: 0.1592 - val_accuracy: 0.0000e+00
# Epoch 12/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1377 - accuracy: 0.0164 - val_loss: 0.1497 - val_accuracy: 0.0000e+00
# Epoch 13/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1364 - accuracy: 0.0000e+00 - val_loss: 0.1388 - val_accuracy: 0.0000e+00
# Epoch 14/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1211 - accuracy: 0.0164 - val_loss: 0.1490 - val_accuracy: 0.0000e+00
# Epoch 15/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1327 - accuracy: 0.0000e+00 - val_loss: 0.1422 - val_accuracy: 0.0000e+00
# Epoch 16/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1094 - accuracy: 0.0000e+00 - val_loss: 0.1203 - val_accuracy: 0.0000e+00
# Epoch 17/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0980 - accuracy: 0.0000e+00 - val_loss: 0.1153 - val_accuracy: 0.0000e+00
# Epoch 18/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1011 - accuracy: 0.0000e+00 - val_loss: 0.1312 - val_accuracy: 0.0000e+00
# Epoch 19/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0989 - accuracy: 0.0000e+00 - val_loss: 0.1137 - val_accuracy: 0.0000e+00
# Epoch 20/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0942 - accuracy: 0.0164 - val_loss: 0.1158 - val_accuracy: 0.0000e+00
# Epoch 21/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0953 - accuracy: 0.0000e+00 - val_loss: 0.1227 - val_accuracy: 0.0000e+00
# Epoch 22/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0979 - accuracy: 0.0000e+00 - val_loss: 0.1237 - val_accuracy: 0.0000e+00
# Epoch 23/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1001 - accuracy: 0.0164 - val_loss: 0.1159 - val_accuracy: 0.0000e+00
# Epoch 24/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0924 - accuracy: 0.0000e+00 - val_loss: 0.1112 - val_accuracy: 0.0000e+00
# Epoch 25/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0915 - accuracy: 0.0000e+00 - val_loss: 0.1097 - val_accuracy: 0.0000e+00

# %%
import matplotlib.pyplot as plt
plt.figure(5, figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(historia.history["loss"], label="Pérdida set entrenamiento")
plt.plot(historia.history["val_loss"], label="Pérdida set prueba")
plt.xlabel('Epocas')
plt.legend()
plt.subplot(1,2,2)
plt.plot(historia.history["accuracy"], label="Tasa de acierto en entrenamiento")
plt.plot(historia.history["val_accuracy"], label="Tasa de acierto en teste")
plt.xlabel('Epocas')
plt.legend()

# %% [markdown]
# Una vez entrenado el modelo con el set correspondiente a las señales Tor, se extrae la representación contenida en el "bottleneck" del AutoEncoder.

# %%
bottleneck = Model(entrada, encoded)
rep_test_3 = bottleneck.predict(D_test_s3)
print(rep_test_3.shape)
# Out:
# (6, 50)

# %% [markdown]
# **2.3. Representaciones de menor Dimensión**

# %% [markdown]
# Una vez entrenado el autoencoder extraemos la información aprendida de la capa de menor dimensión, la cual consigue representar mejor la señal.
#
# A continuación se presenta una representación por cada tipo de señal solo para poder identificar las diferntes representaciones obtenidas.

# %%
Representación = Model(inputs=entrada, outputs=encoded)
Representación.summary

# Observamos cómo el Autoencoder consigue representar 

dato = 5    # Elegimos un dato al azar de los registro de los data sets de validación
# El data set con el menor número de datos de validación es para la señal Tor con 6 ejemplos.

plt.figure(figsize=(15,5))
plt.subplot(3,1,1)
plt.plot(represent_1[dato])
plt.legend(labels=["VT"])
plt.subplot(3,1,2)
plt.plot(represent_2[dato])
plt.legend(labels=["LP"])
plt.subplot(3,1,3)
plt.plot(represent_3[dato])
plt.legend(labels=["Tor"])

# %% [markdown]
# # **3. Modelo de AutoEncoder para Clasificación**

# %% [markdown]
# Con las representaciones obtenidas con el modelo de autoencoder anterior, estas son normalizadas y presentadas a un nuevo autoencoder para su posterior clasificación bajo el enfoque de distribución del error de reconstrucción.

# %% [markdown]
# **3.1 Normalización de las representaciones**

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

# Señales VT
Rep_train_s1 = min_max_scaler.fit_transform(represent_1)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(rep_train_1), np.max(rep_train_1)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(Rep_train_s1), np.max(Rep_train_s1))) 
Rep_test_s1 = min_max_scaler.transform(rep_test_1)  

# Señales LP
D_train_s2 = min_max_scaler.fit_transform(SA_train_2)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(SA_train_2), np.max(SA_train_2)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(D_train_s2), np.max(D_train_s2))) 
D_test_s2 = min_max_scaler.transform(SA_test_2)  

# Señales Tor
D_train_s3 = min_max_scaler.fit_transform(SA_train_3)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(SA_train_3), np.max(SA_train_3)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(D_train_s3), np.max(D_train_s3))) 
D_test_s3 = min_max_scaler.transform(SA_test_3)  

# Graficando
plt.figure(3, figsize=(20, 4))
plt.subplot(231)
plt.plot(t2, D_train_s1[60])
plt.subplot(232)
plt.plot(t2, D_train_s2[18])
plt.subplot(233) 
plt.plot(t2, D_train_s3[38])
plt.subplot(234)
plt.plot(t2, D_test_s1[44])
plt.subplot(235)
plt.plot(t2, D_test_s2[34])
plt.subplot(236)
plt.plot(t2, D_test_s3[4])

# %% [markdown]
# **3.1 Identificación de la distribución del error**

# %%
rec_1 = autoencoder.predict(D_test_s1)
rec_2 = autoencoder.predict(D_test_s2)
rec_3 = autoencoder.predict(D_test_s3)

loss_1 = tf.keras.losses.mae(rec_1, D_test_s1)
loss_2 = tf.keras.losses.mae(rec_2, D_test_s2)
loss_3 = tf.keras.losses.mae(rec_3, D_test_s3)

plt.figure(figsize=(15,8))
plt.hist(loss_1[None,:], bins=100, alpha=0.75, label='VT (1)')
plt.hist(loss_2[None,:], bins=100, alpha=0.75, color='#ff521b', label='LP (2)')
plt.hist(loss_3[None,:], bins=100, alpha=0.75, color='#020122', label='Tor (3)')

plt.xlabel('Pérdidas (MAE)')
plt.ylabel('Nro. ejemplos')
plt.legend(loc='upper right')
plt.vlines(0.08,0,70,'k')

# %% [markdown]
# **3.2 Definición del humbral de clasificación**

# %%
umbral = np.mean(loss_1) + np.std(loss_1)
print("Umbral: ", umbral)
# Out:
# Umbral:  0.053622804673684285

# %% [markdown]
# **3.3 Sensitividad y Especificidad**

# %% [markdown]
# *   **Verdaderos positivos (TP):** anormales que han sido correctamente clasificados como anormales
# *   **Falsos negativos (FN):** anormales que han sido clasificados erróneamente como normales
# *   **Verdaderos negativos (TN):** normales que han sido correctamente clasificados como normales
# *   **Falsos positivos (FP):** normales que han sido clasificados erróneamente como anormales

# %% [markdown]
# La **sensitividad** mide la proporción de anormales que fueron detectados correctamente como anormales. Una sensitividad del 100% detectará a todos los pacientes enfermos:
#
# $$Sensitividad = \dfrac{TP}{TP+FN}$$
#
# La **especificidad** mide la proporción de normales que fueron detectados correctamente como normales. Una especificidad del 100% detectará a todos los pacientes sanos:
# $$Especificidad = \dfrac{TN}{TN+FP}$$

# %%
# Definiendo funciones para la clasificación individual
def identificar(modelo, datos, umbral):
  reconstrucciones = modelo(datos)
  perdida = tf.keras.losses.mae(reconstrucciones, datos)
  return tf.math.less(perdida, umbral)

def calcular_sensitividad(identificacion, titulo):
  TP = np.count_nonzero(~identificacion)
  FN = np.count_nonzero(identificacion)
  sen = 100*(TP/(TP+FN))

  print(titulo + ': {:.1f}%'.format(sen))

def calcular_especificidad(identificacion, titulo):
  TN = np.count_nonzero(identificacion)
  FP = np.count_nonzero(~identificacion)
  esp = 100*(TN/(TN+FP))

  print(titulo + ': {:.1f}%'.format(esp))
  return esp

# %%
# Identificación del tipo de señal
pred_1 = identificar(autoencoder, D_test_s1, umbral)
pred_2 = identificar(autoencoder, D_test_s2, umbral)
pred_3 = identificar(autoencoder, D_test_s3, umbral)

# Calculo de Especificidad
esp_1 = calcular_especificidad(pred_1,'Especificidad (cat. VT, VT)')

# Cálculo de Sensitividad
sen_2 = calcular_sensitividad(pred_2,'Sensitividad (cat. LP, NO VTs)')
sen_3 = calcular_sensitividad(pred_3,'Sensitividad (cat. Tor, NO VTs)')
# Out:
# Especificidad (cat. VT, VT): 97.7%
# Sensitividad (cat. LP, NO VTs): 32.5%
# Sensitividad (cat. Tor, NO VTs): 66.7%

# %% [markdown]
# **3.3 Clasificador II para las señales restantes: LP y Tor**

# %% [markdown]
# Usamos una configuración difernte de AutoEncoder a la anterior por una menos compleja debido a la cantidad de ejemplos disponibles en el data set de entrenamiento, para este caso corresponde a la señal LP, que es el segundo set en cantidad.

# %%
# Encoder
x = Dense(800, activation='relu', kernel_regularizer=l2(0.005))(entrada)
x = Dropout(0.25)(x)
x = Dense(250, activation='relu')(x)
x = Dropout(0.25)(x)
encoded = Dense(50, activation='relu', name='bottleneck_layer')(x)

# Decoder 
x = Dense(250, activation='relu')(encoded)
x = Dropout(0.25)(x)
x = Dense(800, activation='relu')(x)
x = Dropout(0.25)(x)
decoded = Dense(1500, activation='sigmoid')(x)

autoencoder2 = Model(inputs=entrada, outputs=decoded)

autoencoder2.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1500)]            0
#
#  dense_12 (Dense)            (None, 800)               1200800
#
#  dropout_10 (Dropout)        (None, 800)               0
#
#  dense_13 (Dense)            (None, 250)               200250
#
#  dropout_11 (Dropout)        (None, 250)               0
#
#  bottleneck_layer (Dense)    (None, 50)                12550
#
#  dense_14 (Dense)            (None, 250)               12750
#
#  dropout_12 (Dropout)        (None, 250)               0
#
#  dense_15 (Dense)            (None, 800)               200800
#
#  dropout_13 (Dropout)        (None, 800)               0
#
#  dense_16 (Dense)            (None, 1500)              1201500
#
# =================================================================
# Total params: 2,828,650
# Trainable params: 2,828,650
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Optimización y entrenamiento

# %%
autoencoder2.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
historia = autoencoder2.fit(D_train_s2, D_train_s2,    
                           epochs=15,
                           batch_size=30,
                           validation_data=(D_test_s2, D_test_s2),    
                           shuffle=True)
# Out:
# Epoch 1/15
# 13/13 [==============================] - 1s 18ms/step - loss: 4.1586 - accuracy: 0.0000e+00 - val_loss: 2.3242 - val_accuracy: 0.0000e+00
# Epoch 2/15
# 13/13 [==============================] - 0s 7ms/step - loss: 1.5966 - accuracy: 0.2293 - val_loss: 0.8585 - val_accuracy: 0.2500
# Epoch 3/15
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5548 - accuracy: 0.2873 - val_loss: 0.2839 - val_accuracy: 0.2500
# Epoch 4/15
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1832 - accuracy: 0.2873 - val_loss: 0.0972 - val_accuracy: 0.2500
# Epoch 5/15
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0788 - accuracy: 0.2818 - val_loss: 0.0793 - val_accuracy: 0.2500
# Epoch 6/15
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0699 - accuracy: 0.1630 - val_loss: 0.0662 - val_accuracy: 0.0750
# Epoch 7/15
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0595 - accuracy: 0.2265 - val_loss: 0.1204 - val_accuracy: 0.2500
# Epoch 8/15
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0737 - accuracy: 0.1271 - val_loss: 0.0810 - val_accuracy: 0.0750
# Epoch 9/15
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0731 - accuracy: 0.1519 - val_loss: 0.0735 - val_accuracy: 0.0750
# Epoch 10/15
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0655 - accuracy: 0.1685 - val_loss: 0.0676 - val_accuracy: 0.2500
# Epoch 11/15
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0586 - accuracy: 0.2072 - val_loss: 0.0567 - val_accuracy: 0.2500
# Epoch 12/15
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0574 - accuracy: 0.2127 - val_loss: 0.0607 - val_accuracy: 0.2500
# Epoch 13/15
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0596 - accuracy: 0.2265 - val_loss: 0.0641 - val_accuracy: 0.2500
# Epoch 14/15
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0583 - accuracy: 0.2403 - val_loss: 0.1066 - val_accuracy: 0.2500
# Epoch 15/15
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0694 - accuracy: 0.2735 - val_loss: 0.0746 - val_accuracy: 0.2500

# %%
import matplotlib.pyplot as plt
plt.figure(5, figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(historia.history["loss"], label="Pérdida set entrenamiento")
plt.plot(historia.history["val_loss"], label="Pérdida set prueba")
plt.xlabel('Epocas')
plt.legend()
plt.subplot(1,2,2)
plt.plot(historia.history["accuracy"], label="Tasa de acierto en entrenamiento")
plt.plot(historia.history["val_accuracy"], label="Tasa de acierto en teste")
plt.xlabel('Epocas')
plt.legend()

# %%
rec_2 = autoencoder2(D_test_s2).numpy()
rec_3 = autoencoder2(D_test_s3).numpy()

dato = 5    # Elegimos un dato al azar de los registro de los data sets de validación
# El data set con el menor número de datos de validación es para la señal Tor con 6 ejemplos.

plt.figure(figsize=(15,5))
plt.subplot(2,1,1)
plt.plot(D_test_s2[dato],'b')
plt.plot(rec_2[dato],'r')
plt.fill_between(np.arange(1500), rec_2[dato], D_test_s2[dato], color='lightcoral')
plt.legend(labels=["Original anormal", "Reconstruction", "Error"])
plt.subplot(2,1,2)
plt.plot(D_test_s3[dato],'b')
plt.plot(rec_3[dato],'r')
plt.fill_between(np.arange(1500), rec_3[dato], D_test_s3[dato], color='lightcoral')
plt.legend(labels=["Original anormal", "Reconstruction", "Error"])

# %%
rec_2 = autoencoder.predict(D_test_s2)
rec_3 = autoencoder.predict(D_test_s3)

loss_2 = tf.keras.losses.mae(rec_2, D_test_s2)
loss_3 = tf.keras.losses.mae(rec_3, D_test_s3)

plt.figure(figsize=(15,8))
plt.hist(loss_2[None,:], bins=100, alpha=0.75, color='#ff521b', label='LP (2)')
plt.hist(loss_3[None,:], bins=100, alpha=0.75, color='#020122', label='Tor (3)')

plt.xlabel('Pérdidas (MAE)')
plt.ylabel('Nro. ejemplos')
plt.legend(loc='upper right')
plt.vlines(0.08,0,70,'k')

# %%
umbral = np.mean(loss_2) + np.std(loss_2)
print("Umbral: ", umbral)
# Out:
# Umbral:  0.13020050790495685

# %%
# Identificación del tipo de señal
pred_2 = identificar(autoencoder, D_test_s2, umbral)
pred_3 = identificar(autoencoder, D_test_s3, umbral)

# Calculo de Especificidad
esp_2 = calcular_especificidad(pred_2,'Especificidad (cat. LP, LP)')

# Cálculo de Sensitividad
sen_3 = calcular_sensitividad(pred_3,'Sensitividad (cat. Tor, NO LPs)')
# Out:
# Especificidad (cat. LP, LP): 85.0%
# Sensitividad (cat. Tor, NO LPs): 33.3%
